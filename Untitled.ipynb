# %%
print("""Twinkle,twinkle,little star,
                 How i wonder what you are  
                        up above the world so high
                        like a diamond in the sky
         Twinkle,twinkle,little star
                 How i wonder what you are
      
      
      
      
      """)
# Out:
# Twinkle,twinkle,little star,
#                  How i wonder what you are
#                         up above the world so high
#                         like a diamond in the sky
#          Twinkle,twinkle,little star
#                  How i wonder what you are

# %%
from platform import python_version 
python_version()
# Out:
# '3.6.13'

# %%
c=int(input(" Radius (cm):  "))

m= str(3.1415*c*c)
print(m+" cm")
# Out:
#  Radius (cm):  3
# 28.2735cm

# %%
c=input (" First Name:  ")
v=input( " Second Name:   ")
print(f"{v} {c}")
# Out:
#  First Name:  abu
#  Second Name:   bakar
# bakar abu

# %%
v=int(input("Fist Number:  "))
c=int(input("Second Number:"))
b=v+c
print(b)
# Out:
# Fist Number:  3
# Second Number:3
# 6
